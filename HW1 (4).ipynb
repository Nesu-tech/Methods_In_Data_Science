# %% [markdown]
# # Methods in Data Science - Homework 1 - Wilmington College
#
# **Chapter 2: Exercises 8 and 10**

# %% [markdown]
# # 8. College Dataset Analysis
#
# This exercise relates to the College data set, which can be found in the file `College.csv` on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are:
#
# - **Private**: Public/private indicator
# - **Apps**: Number of applications received
# - **Accept**: Number of applicants accepted
# - **Enroll**: Number of new students enrolled
# - **Top10perc**: New students from top 10% of high school class
# - **Top25perc**: New students from top 25% of high school class
# - **F.Undergrad**: Number of full-time undergraduates
# - **P.Undergrad**: Number of part-time undergraduates
# - **Outstate**: Out-of-state tuition
# - **Room.Board**: Room and board costs
# - **Books**: Estimated book costs
# - **Personal**: Estimated personal spending
# - **PhD**: Percent of faculty with Ph.D.s
# - **Terminal**: Percent of faculty with terminal degree
# - **S.F.Ratio**: Student/faculty ratio
# - **perc.alumni**: Percent of alumni who donate
# - **Expend**: Instructional expenditure per student
# - **Grad.Rate**: Graduation rate
#
# Before reading the data into Python, it can be viewed in Excel or a text editor.
#
# #### (a) Read Data into Python
#
# Use the `pd.read_csv()` function to read the data into Python. Call the loaded data `college`. Make sure that you have the directory set to the correct location for the data.
#
# ```python
# import pandas as pd
#
# # Read the data into Python
# college = pd.read_csv('College.csv')
# ```
#
# #### (b) Examine the Data
#
# Look at the data used in the notebook by creating and running a new cell with just the code `college` in it. You should notice that the first column is just the name of each university in a column named something like `Unnamed: 0`. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later. Try the following commands:
#
# ```python
# college2 = pd.read_csv('College.csv', index_col=0)
# college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
# college3 = college3.set_index('College')
# ```
#
# This has used the first column in the file as an index for the data frame. This means that pandas has given each row a name corresponding to the appropriate university. Now you should see that the first data column is `Private`. Note that the names of the colleges appear on the left of the table. We also introduced a new Python object above: a dictionary, which is specified by dictionary (key, value) pairs. Keep your modified version of the data with the following:
#
# ```python
# college = college3
# ```
#
# #### (c) Numerical Summary
#
# Use the `describe()` method to produce a numerical summary of the variables in the data set.
#
#
# #### (d) Scatterplot Matrix
#
# Use the `pd.plotting.scatter_matrix()` function to produce a scatterplot matrix of the first columns `[Top10perc, Apps, Enroll]`. Recall that you can reference a list `C` of columns of a data frame `A` using `A[C]`.
#
#
# #### (e) Boxplots of Outstate vs Private
#
# Use the `boxplot()` method of `college` to produce side-by-side boxplots of `Outstate` versus `Private`.
#
#
# #### (f) Create a New Variable 'Elite'
#
# Create a new qualitative variable, called `Elite`, by binning the `Top10perc` variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.
#
# ```python
# college['Elite'] = pd.cut(college['Top10perc'], [0, 0.5, 1], labels=['No', 'Yes'])
# ```
#
# Use the `value_counts()` method of `college['Elite']` to see how many elite universities there are. Finally, use the `boxplot()` method again to produce side-by-side boxplots of `Outstate` versus `Elite`.
#
#
# #### (g) Histograms
#
# Use the `plot.hist()` method of `college` to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command `plt.subplots(2, 2)` may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments, you can divide the screen up in other combinations.
#
#
# #### (h) Summary
#
# Continue exploring the data, and provide a brief summary of what you discover.

# %%
import pandas as pd 
from pandas import DataFrame 
import numpy as np 
print("All libraries loaded successfully")

#(a)
college = pd.read_csv("/workspaces/Methods_In_Data_Science/College.csv")
college

#(b)
college2 = pd.read_csv('College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
college3 = college3.set_index('College')
college = college3
college
# Out:
# All libraries loaded successfully
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
# ...

# %%
#(c).Data Summary 
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
#(d)Scatterplot Matrix 
import matplotlib.pyplot as plt

scattermatrix = pd.plotting.scatter_matrix(
    college[["Top10perc", "Apps", "Enroll"]],
    figsize=(10, 8)
)
plt.show()

# %%
#(e) Boxplot of Outstate by Private
import seaborn as sns
sns.boxplot(x="Private", y="Outstate", data=college)
title = "Boxplot of Outstate by Private"
plt.title(title)
plt.show()

# %%
#(f)creating a new variable "Elite"
college["Elite"] = pd.cut(college["Top10perc"], bins=[0, 50, 100], labels=["No", "Yes"])
var_counts = college["Elite"].value_counts()
print(var_counts)

sns.boxplot(x="Elite", y="Outstate", data=college)
title = "Boxplot of Outstate by Elite"
plt.title(title)
plt.show()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
#(g)Histograms with different bins of few quantitative variables 
fig = plt.figure()
hist1 = fig.add_subplot(2,2,1)
hist1.hist(college["Top10perc"], bins=10)   
hist1.set_title("Histogram of Top10perc")
hist2 = fig.add_subplot(2,2,2)
hist2.hist(college["Enroll"], bins=15)
hist2.set_title("Histogram of Enroll")
hist3 = fig.add_subplot(2,2,3)
hist3.hist(college["F.Undergrad"], bins=20)
hist3.set_title("Histogram of F.Undergrad")
hist4 = fig.add_subplot(2,2,4)
hist4.hist(college["Outstate"], bins=25)
hist4.set_title("Histogram of Outstate")
plt.tight_layout()

# %%
#Summary of the data 
numeric_cols = college.select_dtypes(include=[np.number]).columns
correlation_matrix = college[numeric_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix of Numeric Variables")
plt.show()

# %% [markdown]
# From the correlation matrix above,

# %% [markdown]
# # 10. Boston Housing Data Set Exercise
#
# This exercise involves the Boston housing data set.
#
# #### (a) To begin, load in the `Datasets/Boston.csv` data set, which is part of the ISLP library.
#
#
# #### (b) How many rows are in this data set? How many columns? What do the rows and columns represent?
#
# #### (c) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.
#
# #### (d) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.
#
# #### (e) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.
#
# #### (f) How many of the suburbs in this data set bound the Charles river?
#
# #### (g) What is the median pupil-teacher ratio among the towns in this data set?
#
# #### (h) Which suburb of Boston has the lowest median value of owner-occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.
#
# #### (i) In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.

# %%
#(a) Loading the dataset
import pandas as pd 
boston = pd.read_csv("/workspaces/Methods_In_Data_Science/Boston.csv")
boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat  medv
# ...

# %%
#(b) Number or rows and columns in the dataset
rows, cols = boston.shape
print(f"The dataset has {rows} rows and {cols} columns.")
print(" These rows and columns represent various attributes of the Boston housing data, including crime rate, average number of rooms, and median value of owner-occupied homes.")
# Out:
# The dataset has 506 rows and 14 columns.
#  These rows and columns represent various attributes of the Boston housing data, including crime rate, average number of rooms, and median value of owner-occupied homes.

# %%
#(c)Pairwise scatterplots of the predictors(columns)
import matplotlib as plt 
import seaborn as sns 
column = boston.select_dtypes(include=[np.number]).columns
sns.pairplot(boston[column])
plt.pyplot.show()

# %%
#(d)Are any of the predictors associated with per capita crime rate? If so, explain the relationship.
print("From the pairwise scatterplots above,the predictors associated with per capita crime rate (crim) include: rm (average number of rooms per dwelling), dis (weighted distances to five Boston employment centers), and lstat (percentage of lower status of the population).")
print("This is because as the average number of rooms per dwelling (rm) increases, the per capita crime rate (crim) tends to decrease, indicating a negative relationship")
print("Similarly, as the weighted distances to employment centers (dis) increase, the per capita crime rate (crim) tends to decrease, suggesting that areas farther from employment centers have lower crime rates")
print("Conversely, as the percentage of lower status of the population (lstat) increases, the per capita crime rate (crim) tends to increase, indicating a positive relationship.")
# Out:
# From the pairwise scatterplots above,the predictors associated with per capita crime rate (crim) include: rm (average number of rooms per dwelling), dis (weighted distances to five Boston employment centers), and lstat (percentage of lower status of the population).
# This is because as the average number of rooms per dwelling (rm) increases, the per capita crime rate (crim) tends to decrease, indicating a negative relationship
# Similarly, as the weighted distances to employment centers (dis) increase, the per capita crime rate (crim) tends to decrease, suggesting that areas farther from employment centers have lower crime rates
# Conversely, as the percentage of lower status of the population (lstat) increases, the per capita crime rate (crim) tends to increase, indicating a positive relationship.

# %%
#(e)Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
#  The Boston surbubs appear to have a wide range of crime rates, tax rates, and pupil-teacher ratios.
#  The per capita crime rate (crim) ranges from 0.00632 to 88.9762, indicating that some suburbs have very low crime rates while others have extremely high rates.
#  The property tax rate (tax) ranges from 187 to 711, suggesting that there is significant variation in the tax burden across different suburbs.
#  The pupil-teacher ratio (ptratio) ranges from 12.6 to 22, indicating that some suburbs have a much higher number of students per teacher compared to others.

# %%
#(f)How many of the suburbs in this data set bound the Charles river?
sum(boston['chas'] == 1)
print("The sum of ")
# Out:
# 35

# %%
#(g)What is the median pupil-teacher ratio among the towns in this data set?

# %%
#(h)Which suburb of Boston has the lowest median value of owner-occupied homes?
#(h1)What are the values of the other predictors for that suburb
#(h2)how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
#(g)In this data set, how many of the suburbs average more than seven rooms per dwelling?
#(g1)More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.
